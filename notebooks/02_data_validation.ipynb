# %% [markdown]
# # 02 — Data Validation
#
# This notebook mirrors `src/network_security/components/data_validation.py`.
#
# Current pipeline behavior:
#
# ```text
# train.csv + test.csv
#         ↓
# read schema YAML
#         ↓
# validate number of columns
#         ↓
# KS-test drift detection
#         ↓
# report.yaml
#         ↓
# validated/train.csv + validated/test.csv
#         ↓
# DataValidationArtifact
# ```
#
# > **Baseline notebook:** reproduce, inspect, and test the current ML pipeline behavior first. Future upgrades should be added below the baseline sections and integrated into `src/` only after validation.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise FileNotFoundError("Open this notebook from inside the project repository.")

PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Current implementation inspection
#
# Inspect `DataValidation`, `DataValidationConfig`, `DataValidationArtifact`, schema constants, and the schema YAML.

# %% [markdown]
# ## Load current artifacts
#
# Locate the latest or selected ingestion `train.csv` and `test.csv`.

# %% [markdown]
# ## Schema inspection
#
# Load the schema and compare expected columns with actual columns.

# %% [markdown]
# ## Column-count validation
#
# Reproduce the current `validate_number_of_columns()` behavior.

# %% [markdown]
# ## Dataset drift baseline
#
# Reproduce the current per-column `scipy.stats.ks_2samp` test and current `report.yaml` structure.

# %% [markdown]
# ## Validated output artifacts
#
# Write and verify validated train/test files and construct the baseline artifact.

# %% [markdown]
# ## Known baseline limitations
#
# Record: schema-path consistency, column-count-only validation, no dtype validation, KS-test suitability for discrete features, missing-value handling, and artifact-path behavior.

# %%
from src.network_security.entity.config_entity import DataValidationConfig, TrainingPipelineConfig
from src.network_security.entity.artifact_entity import DataIngestionArtifact
from src.network_security.components.data_validation import DataValidation
from src.network_security.utils.main_utils.utils import read_yaml_file
from scipy.stats import ks_2samp

# %%
# Select existing ingestion artifacts or provide paths manually.
# This cell is intentionally editable because artifact timestamps change.
SCHEMA_CANDIDATES = [
    PROJECT_ROOT / "configs" / "schema" / "schema.yaml",
    PROJECT_ROOT / "data_schema" / "schema.yaml",
]
for path in SCHEMA_CANDIDATES:
    print(path, path.exists())

# %% [markdown]
# ## Future experiment area
#
# Keep the baseline implementation above unchanged. Add controlled experiments below:
#
# ```text
# Hypothesis → Implementation → Validation → Comparison → Keep / Reject
# ```

# %%
# Add future experiments here.
