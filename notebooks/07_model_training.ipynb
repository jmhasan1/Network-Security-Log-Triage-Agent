# %% [markdown]
# # 07 — Model Training
#
# This notebook mirrors the model-selection portion of `src/network_security/components/model_trainer.py`.
#
# Current production candidates:
#
# - Random Forest
# - Decision Tree
# - Gradient Boosting
# - Logistic Regression
# - AdaBoost
#
# Current hyperparameter search behavior should be reproduced before we change algorithms or search strategy.
#
# > **Baseline notebook:** reproduce, inspect, and test the current ML pipeline behavior first. Future upgrades should be added below the baseline sections and integrated into `src/` only after validation.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise FileNotFoundError("Open this notebook from inside the project repository.")

PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Load transformed arrays
#
# Split `.npy` arrays into X/y using the final column as the target.

# %% [markdown]
# ## Current candidate definitions
#
# Instantiate the same model families.

# %% [markdown]
# ## Current parameter grids
#
# Recreate the existing search spaces.

# %% [markdown]
# ## Current evaluation helper
#
# Inspect and reproduce `evaluate_models()` behavior from project utilities.

# %% [markdown]
# ## Best-model selection
#
# Verify the current selection logic and resulting fitted estimator.

# %% [markdown]
# ## Train/test metrics
#
# Reproduce F1, precision, and recall artifacts.

# %% [markdown]
# ## Save baseline model
#
# Test the current model-saving path without changing production code.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier

models = {
    "Random Forest": RandomForestClassifier(verbose=1),
    "Decision Tree": DecisionTreeClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(verbose=1),
    "Logistic Regression": LogisticRegression(verbose=1),
    "AdaBoost": AdaBoostClassifier(),
}

# %%
params = {
    "Decision Tree": {"criterion": ["gini", "entropy", "log_loss"]},
    "Random Forest": {"n_estimators": [8, 16, 32, 128, 256]},
    "Gradient Boosting": {
        "learning_rate": [.1, .01, .05, .001],
        "subsample": [0.6, 0.7, 0.75, 0.85, 0.9],
        "n_estimators": [8, 16, 32, 64, 128, 256],
    },
    "Logistic Regression": {},
    "AdaBoost": {
        "learning_rate": [.1, .01, .001],
        "n_estimators": [8, 16, 32, 64, 128, 256],
    },
}

# %% [markdown]
# ## Future experiment area
#
# Keep the baseline implementation above unchanged. Add controlled experiments below:
#
# ```text
# Hypothesis → Implementation → Validation → Comparison → Keep / Reject
# ```

# %%
# Add future experiments here.
