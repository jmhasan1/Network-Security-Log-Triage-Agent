# %% [markdown]
# # 05 — Feature Engineering
#
# This notebook is an **experimental layer**, intentionally separated from the current transformation component.
#
# The current pipeline does not perform explicit feature engineering beyond imputation. This notebook establishes a baseline before we test feature selection or engineered features.
#
# > **Baseline notebook:** reproduce, inspect, and test the current ML pipeline behavior first. Future upgrades should be added below the baseline sections and integrated into `src/` only after validation.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise FileNotFoundError("Open this notebook from inside the project repository.")

PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Baseline feature inventory
#
# List all current input features and their distributions.

# %% [markdown]
# ## Feature quality
#
# Check constant, near-constant, duplicate, and highly correlated features.

# %% [markdown]
# ## Feature relevance
#
# Establish baseline mutual information and model-based importance experiments later.

# %% [markdown]
# ## Leakage review
#
# Verify candidate features do not leak target information.

# %% [markdown]
# ## Feature experiments
#
# Reserved for correlation filtering, variance thresholds, mutual information, RFE, and domain-driven features.

# %% [markdown]
# ## Decision log
#
# Record which experiments are accepted before integration.

# %%
TARGET_COLUMN = "Result"
RAW_DATA_PATH = PROJECT_ROOT / "data" / "raw" / "phisingData.csv"
df = pd.read_csv(RAW_DATA_PATH)
X = df.drop(columns=[TARGET_COLUMN])
y = df[TARGET_COLUMN].replace(-1, 0)
print("Feature count:", X.shape[1])

# %%
constant_features = [c for c in X.columns if X[c].nunique(dropna=False) <= 1]
print("Constant features:", constant_features)

# %% [markdown]
# ## Future experiment area
#
# Keep the baseline implementation above unchanged. Add controlled experiments below:
#
# ```text
# Hypothesis → Implementation → Validation → Comparison → Keep / Reject
# ```

# %%
# Add future experiments here.
