# %% [markdown]
# # 10 — Experiment Tracking
#
# This notebook mirrors the current MLflow tracking logic inside `ModelTrainer.track_mlflow()`.
#
# Current tracked information includes:
#
# - train/test F1
# - train/test precision
# - train/test recall
# - model parameters
# - train/test sample counts
# - algorithm
# - model/framework/project/dataset tags
# - MLflow model artifact
# - optional remote model registration
#
#
# > **Baseline notebook:** reproduce, inspect, and test the current ML pipeline behavior first. Future upgrades should be added below the baseline sections and integrated into `src/` only after validation.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise FileNotFoundError("Open this notebook from inside the project repository.")

PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Environment inspection
#
# Check whether MLflow tracking environment variables are configured without printing secrets.

# %% [markdown]
# ## Tracking URI
#
# Inspect the configured tracking backend and scheme.

# %% [markdown]
# ## Baseline experiment
#
# Log one controlled baseline run.

# %% [markdown]
# ## Metrics and parameters
#
# Reproduce the current metric/parameter names.

# %% [markdown]
# ## Tags
#
# Reproduce current project metadata tags.

# %% [markdown]
# ## Model logging
#
# Test model artifact logging.

# %% [markdown]
# ## Run inspection
#
# Query or inspect the resulting run.

# %% [markdown]
# ## Future experiments
#
# Dataset versions, git commit tags, pipeline version, richer artifacts, and experiment naming conventions.

# %%
import os
import mlflow
from urllib.parse import urlparse

tracking_uri = os.getenv("MLFLOW_TRACKING_URI")
print("MLFLOW_TRACKING_URI configured:", bool(tracking_uri))
if tracking_uri:
    mlflow.set_tracking_uri(tracking_uri)
    print("Tracking scheme:", urlparse(mlflow.get_tracking_uri()).scheme)

# %% [markdown]
# ## Future experiment area
#
# Keep the baseline implementation above unchanged. Add controlled experiments below:
#
# ```text
# Hypothesis → Implementation → Validation → Comparison → Keep / Reject
# ```

# %%
# Add future experiments here.
