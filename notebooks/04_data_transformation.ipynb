# %% [markdown]
# # 04 — Data Transformation
#
# This notebook mirrors `src/network_security/components/data_transformation.py`.
#
# Current baseline:
#
# ```text
# validated train/test CSV
#         ↓
# separate X and Result
#         ↓
# Result: -1 → 0
#         ↓
# KNNImputer(n_neighbors=3, weights='uniform')
#         ↓
# fit on train / transform train and test
#         ↓
# append target
#         ↓
# train.npy + test.npy + preprocessing.pkl
# ```
#
# > **Baseline notebook:** reproduce, inspect, and test the current ML pipeline behavior first. Future upgrades should be added below the baseline sections and integrated into `src/` only after validation.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise FileNotFoundError("Open this notebook from inside the project repository.")

PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Inspect current component
#
# Review constants, `DataTransformationConfig`, and `DataTransformationArtifact`.

# %% [markdown]
# ## Load validated data
#
# Load the current validated train/test files.

# %% [markdown]
# ## Target conversion
#
# Reproduce the current `-1 → 0` conversion.

# %% [markdown]
# ## Preprocessor baseline
#
# Build exactly the current `Pipeline([('imputer', KNNImputer(...))])`.

# %% [markdown]
# ## Fit/transform
#
# Fit only on training features and transform train/test.

# %% [markdown]
# ## Array construction
#
# Reproduce `np.c_` creation with the target as the final column.

# %% [markdown]
# ## Artifact verification
#
# Save/reload `.npy` arrays and preprocessing object.

# %% [markdown]
# ## Baseline limitations
#
# Record assumptions: all features numeric, no scaling/encoding, KNN imputation choice, target conversion, and feature-order dependency.

# %%
from sklearn.impute import KNNImputer
from sklearn.pipeline import Pipeline
TARGET_COLUMN = "Result"
IMPUTER_PARAMS = {"missing_values": np.nan, "n_neighbors": 3, "weights": "uniform"}

# %%
# After selecting validated files:
# train_df = pd.read_csv(TRAIN_PATH)
# test_df = pd.read_csv(TEST_PATH)

# Baseline processor:
preprocessor = Pipeline([("imputer", KNNImputer(**IMPUTER_PARAMS))])

# %% [markdown]
# ## Future experiment area
#
# Keep the baseline implementation above unchanged. Add controlled experiments below:
#
# ```text
# Hypothesis → Implementation → Validation → Comparison → Keep / Reject
# ```

# %%
# Add future experiments here.
