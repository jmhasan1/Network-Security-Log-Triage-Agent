# %% [markdown]
# # 08 — Model Evaluation
#
# This notebook isolates evaluation from training.
#
# The current project uses `ClassificationMetricArtifact` with:
#
# - F1 score
# - Precision
# - Recall
#
# This notebook first reproduces those exact metrics and artifacts.
#
# > **Baseline notebook:** reproduce, inspect, and test the current ML pipeline behavior first. Future upgrades should be added below the baseline sections and integrated into `src/` only after validation.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise FileNotFoundError("Open this notebook from inside the project repository.")

PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Load trained model and test data
#
# Use the current transformed test artifact.

# %% [markdown]
# ## Current metrics
#
# Reproduce `get_classification_score()`.

# %% [markdown]
# ## Train/test comparison
#
# Compare current training and testing metrics.

# %% [markdown]
# ## Metric artifact
#
# Construct and inspect `ClassificationMetricArtifact`.

# %% [markdown]
# ## Model comparison view
#
# Create a baseline table for candidate models.

# %% [markdown]
# ## Future evaluation upgrades
#
# Reserve ROC-AUC, PR-AUC, confusion matrix, threshold analysis, calibration, and confidence analysis for controlled upgrades.

# %%
from sklearn.metrics import f1_score, precision_score, recall_score
from dataclasses import dataclass

@dataclass
class ClassificationMetricArtifact:
    f1_score: float
    precision_score: float
    recall_score: float

def get_classification_score(y_true, y_pred):
    return ClassificationMetricArtifact(
        f1_score=f1_score(y_true, y_pred),
        precision_score=precision_score(y_true, y_pred),
        recall_score=recall_score(y_true, y_pred),
    )

# %% [markdown]
# ## Future experiment area
#
# Keep the baseline implementation above unchanged. Add controlled experiments below:
#
# ```text
# Hypothesis → Implementation → Validation → Comparison → Keep / Reject
# ```

# %%
# Add future experiments here.
