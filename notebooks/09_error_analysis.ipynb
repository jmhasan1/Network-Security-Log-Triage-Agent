# %% [markdown]
# # 09 — Error Analysis
#
# The current production pipeline has no dedicated error-analysis stage.
#
# This notebook creates a baseline analysis layer without changing the production pipeline. It should examine false positives and false negatives for the currently selected model.
#
# > **Baseline notebook:** reproduce, inspect, and test the current ML pipeline behavior first. Future upgrades should be added below the baseline sections and integrated into `src/` only after validation.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise FileNotFoundError("Open this notebook from inside the project repository.")

PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Load model and test data
#
# Use the current model and matching test features.

# %% [markdown]
# ## Prediction inspection
#
# Create a row-level table containing actual, predicted, and error type.

# %% [markdown]
# ## False positives
#
# Inspect records predicted positive when actual is negative.

# %% [markdown]
# ## False negatives
#
# Inspect records predicted negative when actual is positive.

# %% [markdown]
# ## Feature-pattern comparison
#
# Compare summary statistics across correct and incorrect predictions.

# %% [markdown]
# ## Error log
#
# Document recurring failure patterns.

# %% [markdown]
# ## Future experiments
#
# Reserve SHAP, probability analysis, clustering of errors, and security-cost weighting for later.

# %%
def label_error(y_true, y_pred):
    if y_true == 1 and y_pred == 1: return "TP"
    if y_true == 0 and y_pred == 0: return "TN"
    if y_true == 0 and y_pred == 1: return "FP"
    return "FN"

# %% [markdown]
# ## Future experiment area
#
# Keep the baseline implementation above unchanged. Add controlled experiments below:
#
# ```text
# Hypothesis → Implementation → Validation → Comparison → Keep / Reject
# ```

# %%
# Add future experiments here.
