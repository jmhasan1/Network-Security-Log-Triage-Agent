# %% [markdown]
# # 12 — End-to-End Pipeline Test
#
# This notebook is the integration checkpoint for the current ML pipeline.
#
# It should execute and verify:
#
# ```text
# Data Ingestion
#       ↓
# Data Validation
#       ↓
# Data Transformation
#       ↓
# Model Training
#       ↓
# Saved NetworkModel
#       ↓
# Inference smoke test
# ```
#
# The current production orchestrator is `TrainingPipleine` in `training_pipeline.py`.
#
# > **Baseline notebook:** reproduce, inspect, and test the current ML pipeline behavior first. Future upgrades should be added below the baseline sections and integrated into `src/` only after validation.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise FileNotFoundError("Open this notebook from inside the project repository.")

PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Preflight checks
#
# Verify environment, imports, raw data/source access, and required dependencies.

# %% [markdown]
# ## Instantiate pipeline
#
# Import the current `TrainingPipleine`.

# %% [markdown]
# ## Run component-by-component
#
# Execute ingestion → validation → transformation → training and inspect every artifact.

# %% [markdown]
# ## Artifact integrity
#
# Verify all expected files exist and can be reloaded.

# %% [markdown]
# ## End-to-end run
#
# Optionally call the current `run_pipeline()` after confirming its external sync dependencies.

# %% [markdown]
# ## Inference smoke test
#
# Load the final model and predict on a small valid sample.

# %% [markdown]
# ## Integration report
#
# Record run timestamp, artifact paths, model metrics, failures, and warnings.

# %% [markdown]
# ## Future experiments
#
# After every production upgrade, use this notebook as the regression/integration checkpoint.

# %%
from src.network_security.pipeline.training_pipeline import TrainingPipleine

pipeline = TrainingPipleine()
print("Pipeline initialized successfully:", type(pipeline).__name__)

# %%
# Safer baseline execution: component by component.
# ingestion_artifact = pipeline.start_data_ingestion()
# validation_artifact = pipeline.start_data_validation(ingestion_artifact)
# transformation_artifact = pipeline.start_data_transformation(validation_artifact)
# trainer_artifact = pipeline.start_model_trainer(transformation_artifact)

# Uncomment only after the environment and data source are configured.

# %% [markdown]
# ## Future experiment area
#
# Keep the baseline implementation above unchanged. Add controlled experiments below:
#
# ```text
# Hypothesis → Implementation → Validation → Comparison → Keep / Reject
# ```

# %%
# Add future experiments here.
