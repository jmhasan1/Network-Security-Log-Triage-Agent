# %% [markdown]
# # 11 — Model Inference
#
# This notebook mirrors `NetworkModel` from `utils/ml_utils/model/estimator.py`.
#
# Current inference flow:
#
# ```text
# Raw feature dataframe
#         ↓
# preprocessor.transform(X)
#         ↓
# model.predict(X_transformed)
#         ↓
# prediction
# ```
#
# > **Baseline notebook:** reproduce, inspect, and test the current ML pipeline behavior first. Future upgrades should be added below the baseline sections and integrated into `src/` only after validation.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise FileNotFoundError("Open this notebook from inside the project repository.")

PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Load saved objects
#
# Load the saved preprocessor and trained model/network model.

# %% [markdown]
# ## Input contract
#
# Verify required feature columns and ordering.

# %% [markdown]
# ## Single-record inference
#
# Test one input record.

# %% [markdown]
# ## Batch inference
#
# Test multiple records.

# %% [markdown]
# ## Pipeline equivalence
#
# Compare direct model predictions with `NetworkModel.predict()`.

# %% [markdown]
# ## Serialization check
#
# Reload the saved object and confirm prediction consistency.

# %% [markdown]
# ## Future experiments
#
# Probability output, thresholding, validation at inference, explanations, risk scores, and structured triage output.

# %%
import joblib

class NetworkModel:
    def __init__(self, preprocessor, model):
        self.preprocessor = preprocessor
        self.model = model

    def predict(self, x):
        x_transform = self.preprocessor.transform(x)
        return self.model.predict(x_transform)

# %% [markdown]
# ## Future experiment area
#
# Keep the baseline implementation above unchanged. Add controlled experiments below:
#
# ```text
# Hypothesis → Implementation → Validation → Comparison → Keep / Reject
# ```

# %%
# Add future experiments here.
